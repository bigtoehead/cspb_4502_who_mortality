# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
from scipy import stats
# %matplotlib inline

# %%
 df = pd.read_csv("CList_104_ordered.csv")

clean = open('CList_104_ordered.csv','r')
cleaner = open('CList_104_ordered_cleaner.csv','w')
    
for line in clean.readlines():
    ll = len(line.split(','))
    new_line = ''
    for i in range(ll):
        if i < ll-1:
            new_line = new_line+line.split(',')[i].replace(' ','')+','
        else:
            new_line = new_line+line.split(',')[i].replace(' ','')
    print(new_line)
    cleaner.writelines(new_line)

clean.close()
cleaner.close()
# Out:
# Country_ID,Country_Name,Sex,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018
#
# 1300,Mauritius,1,517,521,527,533,540,548,556,563,569,574,579,583,588,592,596,599,602,606,609,612,614,617,619,620,621,622,623,624,625,625,626
#
# 1303,Mayotte,1,44,46,48,51,54,57,60,63,65,68,71,74,76,78,81,83,85,88,90,93,96,99,102,105,108,111,115,118,121,124,128
#
# 1310,Morocco,1,11924,12151,12376,12598,12816,13029,13233,13427,13610,13784,13951,14111,14269,14424,14577,14731,14886,15045,15208,15375,15550,15740,15947,16173,16416,16669,16923,17171,17410,17643,17869
#
# 1360,Reunion,1,288,293,299,304,310,317,323,329,335,341,347,353,360,366,372,378,384,388,392,395,397,400,402,405,408,412,415,418,421,424,427
#
# 1520,Tunisia,1,3964,4057,4152,4248,4345,4440,4529,4609,4680,4743,4798,4846,4889,4927,4959,4989,5022,5058,5101,5149,5201,5253,5303,5350,5395,5440,5488,5542,5601,5665,5732
#
# ...
